# %% [markdown]
# ### Load ENV variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-3.8-flash",
    temperature=0.7
)

response = llm.invoke("What is the capital of France?")

print(response.content)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# [{'type': 'text', 'text': 'The capital of France is **Paris**.', 'extras': {'signature': '...'}}]

# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-3.8-flash",
    temperature=0.7
)

response = llm.invoke("What was the PM of bangladesh in 2001?")

print(response.content)
# Out:
# [{'type': 'text', 'text': 'In 2001, Bangladesh had **two different Prime Ministers** due to a general election held that year, as well as an interim leader:\n\n1. **Sheikh Hasina** \n   * **Term:** Until July 15, 2001 \n   * *Party:* Awami League\n\n2. **Latifur Rahman** *(Chief Adviser / Head of Caretaker Government)*\n   * **Term:** July 15, 2001 – October 10, 2001 \n   * *Role:* Led the non-partisan interim government overseeing the elections (equivalent to Prime Minister).\n\n3. **Khaleda Zia** \n   * **Term:** Took office on October 10, 2001 (served through 2006)\n   * *Party:* Bangladesh Nationalist Party (BNP)', 'extras': {'signature': '...'}}]

# %% [markdown]
# ### COnnect with Google Gemini Model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-3.8-flash")

# %%
response = llm.invoke("What is Gen AI in short?")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': '**Generative AI (Gen AI)** is a type of artificial intelligence that can **create new content**—such as text, images, audio, video, and code—rather than just analyzing existing data.\n\n* **How it works:** It learns patterns from massive amounts of data and uses that knowledge to generate original, human-like responses to prompts.\n* **Key difference:** Traditional AI *analyzes and predicts* (e.g., recommending a movie or detecting spam); Gen AI *creates* (e.g., writing a script or generating art).\n* **Examples:** ChatGPT (text), Midjourney / DALL-E (images), and GitHub Copilot (code).', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.8-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a06d70-a98f-7b93-8f66-eb54eee5bbff-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 387, 'total_tokens': 39
# ...

# %%
from google import genai
import os

client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

for model in client.models.list():
    print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-3.5-flash-lite
# models/gemini-omni-flash-preview
# models/gemini-omni-1.1-flash
# models/gemini-3.5-transcribe
# models/gemini-3.6-flash
# models/gemini-3.7-flash
# models/gemini-3.8-flash
# models/lyria-3-clip-preview
# ...

# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-3.5-flash-lite",
    temperature=0.7
)

response = llm.invoke("What is Artificial Intelligence?")
print(response.content)
# Out:
# d:\GenAI\env\Lib\site-packages\langchain_google_genai\chat_models.py:3908: UserWarning: Model 'gemini-3.5-flash-lite' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# ...

# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from IPython.display import Markdown, display

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-3.5-flash-lite",
    temperature=0.7
)

question = "What is Artificial Intelligence?"

response = llm.invoke(question)

# Gemini content extraction
if isinstance(response.content, list):
    answer = "\n".join(
        item["text"]
        for item in response.content
        if item.get("type") == "text"
    )
else:
    answer = response.content

display(Markdown(f"""
# 🤖 Gemini Response

### 📝 Question
{question}

### 💡 Answer
{answer}
"""))
# Out:
# d:\GenAI\env\Lib\site-packages\langchain_google_genai\chat_models.py:3908: UserWarning: Model 'gemini-3.5-flash-lite' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# # 🤖 Gemini Response
#
# ### 📝 Question
# What is Artificial Intelligence?
#
# ### 💡 Answer
# At its simplest, **Artificial Intelligence (AI)** refers to the simulation of human intelligence in machines programmed to think, learn, adapt, and solve problems like humans.
#
# It is a broad field of computer science focused on creating systems capable of performing tasks that typically require human cognition, such as reasoning, learning from experience, perceiving complex environments, and understanding natural language.
#
# Here is a breakdown to help you understand AI better:
#
# ---
#
# ### 1. How Does AI Work?
# Traditional computer programs follow strict, pre-written rules: *If X happens, do Y.*
#
# ...

# %% [markdown]
# ### System Prompt

# %%
from langchain_core.messages import SystemMessage, HumanMessage
from IPython.display import Markdown, display

# System Prompt
system_prompt = """
You are a helpful AI tutor.

Explain technical concepts in simple and beginner-friendly language.
Use clear headings and bullet points.
Give practical examples when appropriate.
"""

# User Prompt
user_prompt = """
What is Generative AI?
"""

# Send messages
messages = [
    SystemMessage(content=system_prompt),
    HumanMessage(content=user_prompt)
]

# AI Response
response = llm.invoke(messages)

# Extract clean text
if isinstance(response.content, list):
    answer = "\n".join(
        item["text"]
        for item in response.content
        if item.get("type") == "text"
    )
else:
    answer = response.content

# Beautiful output
display(Markdown(f"""
# 💬 Prompt Conversation

---

## ⚙️ System Prompt

> {system_prompt.strip().replace(chr(10), chr(10) + '> ')}

---

## 👤 User Prompt

**{user_prompt.strip()}**

---

## 🤖 AI Response

{answer}

---
"""))
# Out:
# d:\GenAI\env\Lib\site-packages\langchain_google_genai\chat_models.py:3908: UserWarning: Model 'gemini-3.5-flash-lite' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# # 💬 Prompt Conversation
#
# ---
#
# ## ⚙️ System Prompt
#
# > You are a helpful AI tutor.
# >
# > Explain technical concepts in simple and beginner-friendly language.
# > Use clear headings and bullet points.
# > Give practical examples when appropriate.
#
# ---
#
# ## 👤 User Prompt
#
# **What is Generative AI?**
#
# ---
#
# ## 🤖 AI Response
#
# Welcome! Let’s explore **Generative AI** (often called "GenAI") in a simple, easy-to-understand way.
#
# ---
#
# ### What is Generative AI?
#
# In short, **Generative AI is a type of artificial intelligence that can create brand-new content.**
#
# ...
